# %%
import pandas as pd

cancelled_orders = pd.read_csv('cancelled_orders.csv')

# %%
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:Aniket%40123@localhost:5432/postgres')

# %%
cancelled_orders.to_sql('cancelled_orders', engine, if_exists='replace', index=False)
print('Cancelled orders saved to PostgreSQL!')
# Out:
# Cancelled orders saved to PostgreSQL!

# %%
import pandas as pd

result = pd.read_sql('SELECT * FROM cancelled_orders LIMIT 5;', engine)
print(result)
# Out:
#    Invoice StockCode                    Description  Quantity  \
# 0  C489449     22087       PAPER BUNTING WHITE LACE       -12
# 1  C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 2  C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 3  C489449     21896             POTTING SHED TWINE        -6
# 4  C489449     22083     PAPER CHAIN KIT RETRO SPOT       -12
#
#            InvoiceDate  Price  Customer ID    Country
# 0  2009-12-01 10:33:00   2.95      16321.0  Australia
# 1  2009-12-01 10:33:00   1.65      16321.0  Australia
# 2  2009-12-01 10:33:00   4.25      16321.0  Australia
# 3  2009-12-01 10:33:00   2.10      16321.0  Australia
# 4  2009-12-01 10:33:00   2.95      16321.0  Australia

# %%
   load_dotenv()

   password = os.getenv("DB_PASSWORD")
   engine = create_engine(f"postgresql://postgres:{password}@localhost:5432/dbname")import os 
   from dotenv import load_dotenv
import os
   load_dotenv()
   
   password = os.getenv("Aniket@123")
   engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/dbname')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       3 load_dotenv()
#       4
#       5 password = os.getenv("Aniket@123")
#
# ModuleNotFoundError: No module named 'dotenv'
